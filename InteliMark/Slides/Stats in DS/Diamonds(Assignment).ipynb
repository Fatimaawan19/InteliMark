# %% [markdown]
#                                                     ASSIGNMENT 1
#                                                         BY
#                                      FATIMA WASEEM FA23-BDS-009 (10-17, 26-34, 51-54 )
#                                      MAHAM ABBAS FA23-BDS-019 (1-9, 35-42, 58-60 )
#                                      RABIA ANJUM FA23-BDS-033 (18-25, 43-50, 55-57 )

# %%
import pandas as pd
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
#                                         ___________________________TASK 1_______________________

# %%
mhm_diamonds = diamonds[diamonds["carat"] > 2]
print(mhm_diamonds[["carat"]])
# Out:
#        carat
# 12246   2.06
# 13002   2.14
# 13118   2.15
# 13757   2.22
# 13991   2.01
# ...      ...
# 27741   2.15
# 27742   2.04
# 27744   2.29
# 27746   2.07
# 27749   2.29
#
# [1889 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", mhm_diamonds["price"].mean())
print("Median : ", mhm_diamonds["price"].median())
print("Mode : ", mhm_diamonds["price"].mode()[0])
print("Standard Deviation : " , mhm_diamonds["price"].std())
print("Variance : " ,mhm_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  14951.250397035468
# Median :  15392.0
# Mode :  16778
# Standard Deviation :  2703.594528249222
# Variance :  7309423.373179133

# %% [markdown]
#                                         ___________________________TASK 2_______________________

# %%
s_diamonds = diamonds[(diamonds["cut"] == "Ideal") & (diamonds["color"] == "D")]
print(s_diamonds[["cut", "color"]])
# Out:
#          cut color
# 62     Ideal     D
# 63     Ideal     D
# 120    Ideal     D
# 132    Ideal     D
# 144    Ideal     D
# ...      ...   ...
# 53854  Ideal     D
# 53855  Ideal     D
# 53884  Ideal     D
# 53935  Ideal     D
# 53939  Ideal     D
#
# [2834 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF CARAT\n")

print("Mean : ", s_diamonds["carat"].mean())
print("Median : ", s_diamonds["carat"].median())
print("Mode : ", s_diamonds["carat"].mode()[0])
print("Standard Deviation : " , s_diamonds["carat"].std())
print("Variance : " , s_diamonds["carat"].var())
# Out:
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  0.5657657021877206
# Median :  0.5
# Mode :  0.31
# Standard Deviation :  0.2993502720823597
# Variance :  0.08961058539578279

# %% [markdown]
#                                         ___________________________TASK 3_______________________

# %%
syeda_diamonds = diamonds[diamonds["price"] > 10000]
print(syeda_diamonds[["price"]])
# Out:
#        price
# 21928  10002
# 21929  10003
# 21930  10004
# 21931  10006
# 21932  10009
# ...      ...
# 27745  18803
# 27746  18804
# 27747  18806
# 27748  18818
# 27749  18823
#
# [5222 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF DEPTH\n")

print("Mean : ", syeda_diamonds["depth"].mean())
print("Median : ", syeda_diamonds["depth"].median())
print("Mode : ", syeda_diamonds["depth"].mode()[0])
print("Standard Deviation : " , syeda_diamonds["depth"].std())
print("Variance : " , syeda_diamonds["depth"].var())
# Out:
# DESCRIPTIVE STATISTICS OF DEPTH
#
# Mean :  61.64798927613942
# Median :  61.8
# Mode :  62.2
# Standard Deviation :  1.4418003790936058
# Variance :  2.078788333154465

# %% [markdown]
#                                         ___________________________TASK 4_______________________

# %%
m_diamonds = diamonds[(diamonds["clarity"] == "VS1") & (diamonds["cut"] == "Good")]
print(m_diamonds[["clarity","cut"]])
# Out:
#       clarity   cut
# 2         VS1  Good
# 35        VS1  Good
# 36        VS1  Good
# 43        VS1  Good
# 96        VS1  Good
# ...       ...   ...
# 53356     VS1  Good
# 53439     VS1  Good
# 53755     VS1  Good
# 53895     VS1  Good
# 53914     VS1  Good
#
# [648 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", m_diamonds["price"].mean())
print("Median : ", m_diamonds["price"].median())
print("Mode : ", m_diamonds["price"].mode()[0])
print("Standard Deviation : " , m_diamonds["price"].std())
print("Variance : " ,m_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  3801.445987654321
# Median :  2434.0
# Mode :  605
# Standard Deviation :  3703.358553829469
# Variance :  13714864.578221897

# %% [markdown]
#                                          ___________________________TASK 5_______________________

# %%
b_diamonds = diamonds[(diamonds["carat"] <= 1) & (diamonds["price"] > 1000)]
print(b_diamonds[["carat","price"]])
# Out:
#        carat  price
# 90      0.70   2757
# 91      0.86   2757
# 92      0.70   2757
# 93      0.71   2759
# 94      0.78   2759
# ...      ...    ...
# 53935   0.72   2757
# 53936   0.72   2757
# 53937   0.70   2757
# 53938   0.86   2757
# 53939   0.75   2757
#
# [21914 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF x\n")

print("Mean : ", b_diamonds["x"].mean())
print("Median : ", b_diamonds["x"].median())
print("Mode : ", b_diamonds["x"].mode()[0])
print("Standard Deviation : " , b_diamonds["x"].std())
print("Variance : " ,b_diamonds["x"].var())
# Out:
# DESCRIPTIVE STATISTICS OF x
#
# Mean :  5.537044355206716
# Median :  5.62
# Mode :  5.72
# Standard Deviation :  0.5254705441688079
# Variance :  0.27611929278906305

# %% [markdown]
#                                         ___________________________TASK 6_______________________

# %%
z_diamonds = diamonds[diamonds["depth"] > 60]
print(z_diamonds[["depth"]])
# Out:
#        depth
# 0       61.5
# 3       62.4
# 4       63.3
# 5       62.8
# 6       62.3
# ...      ...
# 53935   60.8
# 53936   63.1
# 53937   62.8
# 53938   61.0
# 53939   62.2
#
# [48315 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF TABLE\n")

print("Mean : ", z_diamonds["table"].mean())
print("Median : ", z_diamonds["table"].median())
print("Mode : ", z_diamonds["table"].mode()[0])
print("Standard Deviation : " , z_diamonds["table"].std())
print("Variance : " , z_diamonds["table"].var())
# Out:
# DESCRIPTIVE STATISTICS OF TABLE
#
# Mean :  57.1911725137121
# Median :  57.0
# Mode :  56.0
# Standard Deviation :  2.0563551179643293
# Variance :  4.228596371178091

# %% [markdown]
#                                         ___________________________TASK 7_______________________

# %%
zaidi_diamonds = diamonds.query("5000 < price < 10000")
print(zaidi_diamonds[["price"]])
# Out:
#        price
# 11416   5001
# 11417   5001
# 11418   5001
# 11419   5001
# 11420   5001
# ...      ...
# 21922   9997
# 21923   9998
# 21924   9999
# 21925   9999
# 21926   9999
#
# [9491 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", zaidi_diamonds["price"].mean())
print("Median : ", zaidi_diamonds["price"].median())
print("Mode : ", zaidi_diamonds["price"].mode()[0])
print("Standard Deviation : " , zaidi_diamonds["price"].std())
print("Variance : " , zaidi_diamonds["price"].var())

print("\n")
print("DESCRIPTIVE STATISTICS OF CARAT\n")

print("Mean : ", zaidi_diamonds["carat"].mean())
print("Median : ", zaidi_diamonds["carat"].median())
print("Mode : ", zaidi_diamonds["carat"].mode()[0])
print("Standard Deviation : " , zaidi_diamonds["carat"].std())
print("Variance : " , zaidi_diamonds["carat"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  6932.637024549574
# Median :  6653.0
# Mode :  5292
# Standard Deviation :  1409.2286592948772
# Variance :  1985925.414178037
#
#
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  1.2090127489200297
# Median :  1.16
# Mode :  1.01
# Standard Deviation :  0.22922820280856163
# Variance :  0.052545568962843056

# %% [markdown]
#                                      ___________________________TASK 8_______________________

# %%
maham_diamonds = diamonds.query("clarity == 'VVS1' or clarity == 'VVS2'")
print(maham_diamonds[["clarity"]])
# Out:
#       clarity
# 5        VVS2
# 6        VVS1
# 25       VVS2
# 65       VVS2
# 66       VVS1
# ...       ...
# 53885    VVS2
# 53891    VVS1
# 53899    VVS2
# 53912    VVS1
# 53919    VVS1
#
# [8721 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF DEPTH\n")

print("Mean : ", maham_diamonds["depth"].mean())
print("Median : ", maham_diamonds["depth"].median())
print("Mode : ", maham_diamonds["depth"].mode()[0])
print("Standard Deviation : " , maham_diamonds["depth"].std())
print("Variance : " , maham_diamonds["depth"].var())
# Out:
# DESCRIPTIVE STATISTICS OF DEPTH
#
# Mean :  61.64737988762757
# Median :  61.7
# Mode :  62.0
# Standard Deviation :  1.1294668015411162
# Variance :  1.275695255783519

# %% [markdown]
#                                     ___________________________TASK 9 _________________________

# %%
M_diamonds = diamonds.query("x > 7.0 & y < 7.0")
print(M_diamonds[["x","y"]])
# Out:
#           x     y
# 2216   7.01  6.95
# 5078   7.02  6.96
# 5136   7.01  6.96
# 5590   7.02  6.95
# 7975   7.06  6.99
# ...     ...   ...
# 24069  7.03  6.98
# 24477  7.04  6.96
# 27194  7.01  6.95
# 27646  7.43  6.64
# 27677  7.09  6.99
#
# [210 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF CARAT\n")

print("Mean : ", M_diamonds["carat"].mean())
print("Median : ", M_diamonds["carat"].median())
print("Mode : ", M_diamonds["carat"].mode()[0])
print("Standard Deviation : " , M_diamonds["carat"].std())
print("Variance : " , M_diamonds["carat"].var())
# Out:
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  1.293095238095238
# Median :  1.29
# Mode :  1.31
# Standard Deviation :  0.0837999467642685
# Variance :  0.007022431077694235

# %% [markdown]
#                                 ___________________________TASK 10 _________________________

# %%
f_diamonds = diamonds.query("table > 50 & table > 60")
print(f_diamonds[["table"]])
# Out:
#        table
# 1       61.0
# 2       65.0
# 8       61.0
# 9       61.0
# 12      61.0
# ...      ...
# 53895   61.0
# 53897   63.0
# 53902   61.0
# 53918   62.0
# 53931   62.0
#
# [4846 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", f_diamonds["price"].mean())
print("Median : ", f_diamonds["price"].median())
print("Mode : ", f_diamonds["price"].mode()[0])
print("Standard Deviation : " , f_diamonds["price"].std())
print("Variance : " , f_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  4345.981015270326
# Median :  3276.0
# Mode :  540
# Standard Deviation :  3996.8217796310105
# Variance :  15974584.338132797

# %% [markdown]
#                                 ___________________________TASK 11 _________________________

# %%
fw_diamonds = diamonds[(diamonds['cut'] == 'Fair') & (diamonds['price'] < 500)]
print(fw_diamonds[['cut', 'price']])
# Out:
#         cut  price
# 8      Fair    337
# 10030  Fair    416
# 28270  Fair    361
# 31611  Fair    369
# 31615  Fair    371
# 40591  Fair    496
# 40597  Fair    497

# %%
print("DESCRIPTIVE STATISTICS OF CARAT\n")

print("Mean : ", fw_diamonds["carat"].mean())
print("Median : ", fw_diamonds["carat"].median())
print("Mode : ", fw_diamonds["carat"].mode()[0])
print("Standard Deviation : " , f_diamonds["carat"].std())
print("Variance : " , fw_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  0.27285714285714285
# Median :  0.27
# Mode :  0.3
# Standard Deviation :  0.4899314553411162
# Variance :  4309.571428571428

# %% [markdown]
#                                 ___________________________TASK 12 _________________________

# %%
fm_diamonds = diamonds[(diamonds['carat'] > 3) & (diamonds['clarity'] == 'IF')]
print(fm_diamonds[['carat', 'clarity']])
# Out:
# Empty DataFrame
# Columns: [carat, clarity]
# Index: []

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", fm_diamonds["price"].mean())
print("Median : ", fm_diamonds["price"].median())
print("Mode : ", fm_diamonds["price"].mode())
print("Standard Deviation : " , fm_diamonds["price"].std())
print("Variance : " , fm_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  nan
# Median :  nan
# Mode :  Series([], Name: price, dtype: int64)
# Standard Deviation :  nan
# Variance :  nan

# %% [markdown]
#                                 ___________________________TASK 13 _________________________

# %%
fatima_diamonds = diamonds[(diamonds['color'].isin(['G', 'H'])) & (diamonds['cut'] == 'Premium')]
print(fatima_diamonds[['color' , 'cut']])
# Out:
#       color      cut
# 68        G  Premium
# 72        H  Premium
# 73        H  Premium
# 85        G  Premium
# 86        H  Premium
# ...     ...      ...
# 53867     G  Premium
# 53872     H  Premium
# 53880     G  Premium
# 53888     G  Premium
# 53938     H  Premium
#
# [5284 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF TABLE\n")

print("Mean : ", fatima_diamonds["table"].mean())
print("Median : ", fatima_diamonds["table"].median())
print("Mode : ", fatima_diamonds["table"].mode())
print("Standard Deviation : " , fatima_diamonds["table"].std())
print("Variance : " , fatima_diamonds["table"].var())
# Out:
# DESCRIPTIVE STATISTICS OF TABLE
#
# Mean :  58.74241105223316
# Median :  59.0
# Mode :  0    58.0
# Name: table, dtype: float64
# Standard Deviation :  1.494297678001826
# Variance :  2.2329255504816485

# %% [markdown]
#                                 ___________________________TASK 14 _________________________

# %%
f1_diamonds = diamonds[(diamonds['price'] > 2000) & (diamonds['depth'] > 61)]
print(f1_diamonds[['price', 'depth']])
# Out:
#        price  depth
# 90      2757   62.5
# 92      2757   61.6
# 93      2759   62.4
# 94      2759   63.8
# 97      2759   66.3
# ...      ...    ...
# 53933   2757   61.2
# 53934   2757   62.7
# 53936   2757   63.1
# 53937   2757   62.8
# 53939   2757   62.2
#
# [21918 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF X\n")

print("Mean : ", f1_diamonds["x"].mean())
print("Median : ", f1_diamonds["x"].median())
print("Mode : ", f1_diamonds["x"].mode())
print("Standard Deviation : " , f1_diamonds["x"].std())
print("Variance : " , f1_diamonds["x"].var())


print("DESCRIPTIVE STATISTICS OF Y\n")

print("Mean : ", f1_diamonds["y"].mean())
print("Median : ", f1_diamonds["y"].median())
print("Mode : ", f1_diamonds["y"].mode())
print("Standard Deviation : " , f1_diamonds["y"].std())
print("Variance : " , f1_diamonds["y"].var())


print("DESCRIPTIVE STATISTICS OF Z\n")

print("Mean : ", f1_diamonds["z"].mean())
print("Median : ", f1_diamonds["z"].median())
print("Mode : ", f1_diamonds["z"].mode())
print("Standard Deviation : " , f1_diamonds["z"].std())
print("Variance : " , f1_diamonds["z"].var())
# Out:
# DESCRIPTIVE STATISTICS OF X
#
# Mean :  6.52648599324756
# Median :  6.43
# Mode :  0    6.37
# Name: x, dtype: float64
# Standard Deviation :  0.751837054535436
# Variance :  0.5652589565725202
# DESCRIPTIVE STATISTICS OF Y
#
# Mean :  6.525869148644949
# Median :  6.43
# Mode :  0    6.41
# Name: y, dtype: float64
# Standard Deviation :  0.7617476715503585
# Variance :  0.5802595151123928
# DESCRIPTIVE STATISTICS OF Z
#
# Mean :  4.0741021078565565
# Median :  4.02
# Mode :  0    4.01
# Name: z, dtype: float64
# Standard Deviation :  0.4762712810388939
# Variance :  0.226834333142429

# %% [markdown]
#                                 ___________________________TASK 15 _________________________

# %%
f2_diamonds = diamonds[(diamonds['carat'].between(1.5, 2.5)) & (diamonds['clarity'] == 'SI1')]
print(f2_diamonds[['carat', 'clarity']])
# Out:
#        carat clarity
# 11540   1.54     SI1
# 13487   1.50     SI1
# 13778   1.52     SI1
# 14652   1.65     SI1
# 14655   1.50     SI1
# ...      ...     ...
# 27738   2.05     SI1
# 27742   2.04     SI1
# 27744   2.29     SI1
# 27745   2.00     SI1
# 27748   2.00     SI1
#
# [1640 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", f2_diamonds["price"].mean())
print("Median : ", f2_diamonds["price"].median())
print("Mode : ", f2_diamonds["price"].mode())
print("Standard Deviation : " , f2_diamonds["price"].std())
print("Variance : " , f2_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  12138.95
# Median :  11738.0
# Mode :  0    8736
# Name: price, dtype: int64
# Standard Deviation :  3195.5059313592337
# Variance :  10211258.157352045

# %% [markdown]
#                                 ___________________________TASK 16 _________________________

# %%
mean = diamonds['price'].mean()
f3_diamonds = diamonds[diamonds['price'] < mean]
print(f3_diamonds[['price']])
# Out:
#        price
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
# ...      ...
# 53935   2757
# 53936   2757
# 53937   2757
# 53938   2757
# 53939   2757
#
# [34283 rows x 1 columns]

# %%
print("DESCRIPTIVE STATISTICS OF DEPTH\n")

print("Mean : ", f3_diamonds["depth"].mean())
print("Median : ", f3_diamonds["depth"].median())
print("Mode : ", f3_diamonds["depth"].mode())
print("Standard Deviation : " , f3_diamonds["depth"].std())
print("Variance : " , f3_diamonds["depth"].var())


print("DESCRIPTIVE STATISTICS OF CARAT\n")
print("Mean : ", f3_diamonds["carat"].mean())
print("Median : ", f3_diamonds["carat"].median())
print("Mode : ", f3_diamonds["carat"].mode)
# Out:
# DESCRIPTIVE STATISTICS OF DEPTH
#
# Mean :  61.74285797625645
# Median :  61.8
# Mode :  0    61.9
# Name: depth, dtype: float64
# Standard Deviation :  1.3916726551777288
# Variance :  1.9367527791694295
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  0.509338155937345
# Median :  0.44
# Mode :  <bound method Series.mode of 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 34283, dtype: float64>

# %% [markdown]
#                                 ___________________________TASK 17 _________________________

# %%
f4_diamonds = diamonds[(diamonds['clarity'] == 'I1') & (diamonds['cut'] == 'Fair')]
print(f4_diamonds[['clarity', 'cut']])
# Out:
#       clarity   cut
# 241        I1  Fair
# 369        I1  Fair
# 376        I1  Fair
# 967        I1  Fair
# 1199       I1  Fair
# ...       ...   ...
# 52805      I1  Fair
# 52993      I1  Fair
# 53146      I1  Fair
# 53338      I1  Fair
# 53745      I1  Fair
#
# [210 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")

print("Mean : ", f4_diamonds["price"].mean())
print("Median : ", f4_diamonds["price"].median())
print("Mode : ", f4_diamonds["price"].mode())
print("Standard Deviation : " , f4_diamonds["price"].std())
print("Variance : " , f4_diamonds["price"].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  3703.5333333333333
# Median :  2397.0
# Mode :  0    956
# Name: price, dtype: int64
# Standard Deviation :  3098.868944972992
# Variance :  9602988.738118023

# %% [markdown]
#                                 ___________________________TASK 18 _________________________

# %%
ra_diamonds = diamonds[diamonds['x'] > diamonds['x'].median()]
print(ra_diamonds[['price', 'y']])
# Out:
#        price     y
# 91      2757  6.33
# 94      2759  5.85
# 95      2759  5.90
# 96      2759  5.76
# 97      2759  5.95
# ...      ...   ...
# 53931   2756  5.73
# 53932   2757  5.76
# 53935   2757  5.76
# 53938   2757  6.12
# 53939   2757  5.87
#
# [26754 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")
print("Mean : ", ra_diamonds['price'].mean())
print("Median : ", ra_diamonds['price'].median())
print("Mode : ", ra_diamonds['price'].mode())
print("Standard Deviation : " , ra_diamonds['price'].std())
print("Variance : " , ra_diamonds['price'].var())
print("\nDESCRIPTIVE STATISTICS OF Y\n")
print("Mean : ", ra_diamonds['y'].mean())
print("Median : ", ra_diamonds['y'].median())
print("Mode : ", ra_diamonds['y'].mode())
print("Standard Deviation : " , ra_diamonds['y'].std())
print("Variance : " , ra_diamonds['y'].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  6731.482395155865
# Median :  5363.0
# Mode :  0    3669
# Name: price, dtype: int64
# Standard Deviation :  4010.152010807742
# Variance :  16081319.149785375
#
# DESCRIPTIVE STATISTICS OF Y
#
# Mean :  6.688246991104134
# Median :  6.54
# Mode :  0    6.41
# Name: y, dtype: float64
# Standard Deviation :  0.7603857069606245
# Variance :  0.5781864233500087

# %% [markdown]
#                                 ___________________________TASK 19 _________________________

# %%
r1_diamonds = diamonds[diamonds['price'] > diamonds['x'].quantile(0.75)]
print(r1_diamonds['price'])
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")
print("Mean : ", r1_diamonds['price'].mean())
print("Median : ", r1_diamonds['price'].median())
print("Mode : ", r1_diamonds['price'].mode())
print("Standard Deviation : " , r1_diamonds['price'].std())
print("Variance : " , r1_diamonds['price'].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  3932.799721913237
# Median :  2401.0
# Mode :  0    605
# Name: price, dtype: int64
# Standard Deviation :  3989.439738146379
# Variance :  15915629.42430145

# %% [markdown]
#                                 ___________________________TASK 20 _________________________

# %%
r2_diamonds = diamonds[(diamonds['color'] == 'D') & (diamonds['clarity'] == 'VVS2')]
print(r2_diamonds[['color','clarity']])
# Out:
#       color clarity
# 77        D    VVS2
# 78        D    VVS2
# 127       D    VVS2
# 219       D    VVS2
# 675       D    VVS2
# ...     ...     ...
# 53703     D    VVS2
# 53704     D    VVS2
# 53719     D    VVS2
# 53854     D    VVS2
# 53855     D    VVS2
#
# [553 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF DEPTH\n")
print("Mean : ", r2_diamonds['depth'].mean())
print("Median : ", r2_diamonds['depth'].median())
print("Mode : ", r2_diamonds['depth'].mode())
print("Standard Deviation : " , r2_diamonds['depth'].std())
print("Variance : " , r2_diamonds['depth'].var())
# Out:
# DESCRIPTIVE STATISTICS OF DEPTH
#
# Mean :  61.45732368896926
# Median :  61.6
# Mode :  0    62.0
# Name: depth, dtype: float64
# Standard Deviation :  1.3157579227730267
# Variance :  1.73121891133999

# %% [markdown]
#                                 ___________________________TASK 21 _________________________

# %%
r3_diamonds = diamonds[(diamonds['cut'] == 'Ideal') & (diamonds['carat'] > 1.5)]
print(r3_diamonds['price'])
# Out:
# 12129     5170
# 12562     5277
# 13819     5631
# 14230     5766
# 14884     5994
#          ...
# 27735    18780
# 27738    18787
# 27741    18791
# 27746    18804
# 27747    18806
# Name: price, Length: 1539, dtype: int64

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")
print("Mean : ", r3_diamonds['price'].mean())
print("Median : ", r3_diamonds['price'].median())
print("Mode : ", r3_diamonds['price'].mode())
print("Standard Deviation : " , r3_diamonds['price'].std())
print("Variance : " , r3_diamonds['price'].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  13011.421052631578
# Median :  12846.0
# Mode :  0    14482
# Name: price, dtype: int64
# Standard Deviation :  3250.483228770576
# Variance :  10565641.220518786

# %% [markdown]
#                                 ___________________________TASK 22 _________________________

# %%
r4_diamonds = diamonds[(diamonds['x']< 6.5) & (diamonds['y'] > 6)]
print(r4_diamonds[['price', 'carat']])
# Out:
#        price  carat
# 91      2757   0.86
# 108     2761   0.81
# 112     2761   0.90
# 119     2762   0.80
# 128     2763   0.91
# ...      ...    ...
# 53897   2751   1.02
# 53902   2753   0.77
# 53917   2753   0.90
# 53927   2756   0.79
# 53938   2757   0.86
#
# [7756 rows x 2 columns]

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")
print("Mean : ", r4_diamonds['price'].mean())
print("Median : ", r4_diamonds['price'].median())
print("Mode : ", r4_diamonds['price'].mode())
print("Standard Deviation : " , r4_diamonds['price'].std())
print("Variance : " , r4_diamonds['price'].var())

print("\nDESCRIPTIVE STATISTICS OF CARAT\n")
print("Mean : ", r4_diamonds['carat'].mean())
print("Median : ", r4_diamonds['carat'].median())
print("Mode : ", r4_diamonds['carat'].mode())
print("Standard Deviation : " , r4_diamonds['carat'].std())
print("Variance : " , r4_diamonds['carat'].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  4815.144146467251
# Median :  4435.0
# Mode :  0    3669
# Name: price, dtype: int64
# Standard Deviation :  1643.6533598529231
# Variance :  2701596.3673558026
#
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  0.9664221248066013
# Median :  1.0
# Mode :  0    1.01
# Name: carat, dtype: float64
# Standard Deviation :  0.06663856335123719
# Variance :  0.004440698125516852

# %% [markdown]
#                                 ___________________________TASK 23 _________________________

# %%
q1 = diamonds['price'].quantile(0.25)
q3 = diamonds['price'].quantile(0.75)
r5_diamonds = diamonds[(diamonds['price'] >= q1) & (diamonds['price'] >= q3)]
print(r5_diamonds['depth'])
# Out:
# 12765    62.2
# 12766    60.6
# 12767    62.2
# 12768    62.1
# 12769    64.0
#          ...
# 27745    62.8
# 27746    62.5
# 27747    61.7
# 27748    63.5
# 27749    60.8
# Name: depth, Length: 13485, dtype: float64

# %%
print("DESCRIPTIVE STATISTICS OF DEPTH\n")
print("Mean : ", r5_diamonds['depth'].mean())
print("Median : ", r5_diamonds['depth'].median())
print("Mode : ", r5_diamonds['depth'].mode())
print("Standard Deviation : " , r5_diamonds['depth'].std())
print("Variance : " , r5_diamonds['depth'].var())
# Out:
# DESCRIPTIVE STATISTICS OF DEPTH
#
# Mean :  61.72427882832776
# Median :  61.9
# Mode :  0    62.0
# Name: depth, dtype: float64
# Standard Deviation :  1.4507404361506502
# Variance :  2.1046478130825785

# %% [markdown]
#                                 ___________________________TASK 24 _________________________

# %%
r6_diamonds = diamonds[diamonds['cut'] != 'Fair']
print(r6_diamonds['price'])
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 52330, dtype: int64

# %%
print("DESCRIPTIVE STATISTICS OF PRICE\n")
print("Mean : ", r6_diamonds['price'].mean())
print("Median : ", r6_diamonds['price'].median())
print("Mode : ", r6_diamonds['price'].mode())
print("Standard Deviation : " , r6_diamonds['price'].std())
print("Variance : " , r6_diamonds['price'].var())
# Out:
# DESCRIPTIVE STATISTICS OF PRICE
#
# Mean :  3919.6945729027325
# Median :  2370.0
# Mode :  0    605
# Name: price, dtype: int64
# Standard Deviation :  4001.2223131849487
# Variance :  16009779.99952911

# %% [markdown]
#                                 ___________________________TASK 25 _________________________

# %%
r7_diamonds = diamonds[(diamonds['price'] < diamonds['price'].mean()) & (diamonds['depth'] > 60)]
print(r7_diamonds['carat'])
# Out:
# 0        0.23
# 3        0.29
# 4        0.31
# 5        0.24
# 6        0.24
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 31033, dtype: float64

# %%
print("DESCRIPTIVE STATISTICS OF CARAT\n")
print("Mean : ", r7_diamonds['carat'].mean())
print("Median : ", r7_diamonds['carat'].median())
print("Mode : ", r7_diamonds['carat'].mode())
print("Standard Deviation : " , r7_diamonds['carat'].std())
print("Variance : " , r7_diamonds['carat'].var())
# Out:
# DESCRIPTIVE STATISTICS OF CARAT
#
# Mean :  0.5043982212483484
# Median :  0.43
# Mode :  0    0.3
# Name: carat, dtype: float64
# Standard Deviation :  0.20414345060972117
# Variance :  0.04167454842684367

# %% [markdown]
#                                 ___________________________TASK 26 _________________________

# %%
diamonds['price'].mean()
# Out:
# np.float64(3932.799721913237)

# %% [markdown]
#                                 ___________________________TASK 27 _________________________

# %%
diamonds['carat'].median()
# Out:
# np.float64(0.7)

# %% [markdown]
#                                 ___________________________TASK 28 _________________________

# %%
diamonds['cut'].mode()
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %% [markdown]
#                                 ___________________________TASK 29 _________________________

# %%
diamonds['depth'].std()
# Out:
# np.float64(1.432621318833661)

# %% [markdown]
#                                 ___________________________TASK 30 _________________________

# %%
diamonds['table'].var()
# Out:
# np.float64(4.9929480753375515)

# %% [markdown]
#                                 ___________________________TASK 31 _________________________

# %%
f_mean = diamonds['price'].mean()
f_std = diamonds['price'].std()

print("Mean : ", f_mean)
print("Standard Deviation : " , f_std)
# Out:
# Mean :  3932.799721913237
# Standard Deviation :  3989.439738146379

# %% [markdown]
#                                 ___________________________TASK 32 _________________________

# %%
f1_mean = diamonds['x'].mean()
f1_median = diamonds['x'].median()

print("Mean : ", f1_mean)
print("Median : ", f1_median)
# Out:
# Mean :  5.731157211716722
# Median :  5.7

# %% [markdown]
#                                 ___________________________TASK 33 _________________________

# %%
f1_range = diamonds['carat'].max() - diamonds['carat'].min()
print("Range : ", f1_range)
# Out:
# Range :  4.81

# %% [markdown]
#                                 ___________________________TASK 34 _________________________

# %%
diamonds['price'].var()
# Out:
# np.float64(15915629.42430145)

# %% [markdown]
#                                 ___________________________TASK 35 _________________________

# %%
diamonds["y"].std()
# Out:
# np.float64(1.1421346741235552)

# %% [markdown]
#                                 ___________________________TASK 36 _________________________

# %%
diamonds['clarity_encoded'] = diamonds['clarity'].astype('category').cat.codes
diamonds["clarity_encoded"].mean()
# Out:
# np.float64(3.9489803485354096)

# %% [markdown]
#                                 ___________________________TASK 37 _________________________

# %%
m1 = diamonds.groupby("cut", observed= False).agg({'price': 'mean'})
m1
# Out:
#                  price
# cut
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891
# Good       3928.864452
# Fair       4358.757764

# %% [markdown]
#                                 ___________________________TASK 38 _________________________

# %%
m2_diamonds = diamonds[diamonds["carat"] > 1]
mean_price = m2_diamonds["price"].mean()
print("Mean price of diamonds where carat is greater than 1 = ", mean_price)
# Out:
# Mean price of diamonds where carat is greater than 1 =  8400.314706890642

# %% [markdown]
#                                 ___________________________TASK 39 _________________________

# %%
m3_diamonds = diamonds[diamonds["cut"] == "Premium"]
variance_of_price = m3_diamonds["price"].var()
print("Variance of price for diamonds with cut of Premium = " , variance_of_price)
# Out:
# Variance of price for diamonds with cut of Premium =  18915583.79710797

# %% [markdown]
#                                 ___________________________TASK 40 _________________________

# %%
m4_diamonds = diamonds[diamonds["cut"] == 'Ideal']
mode_of_clarity = m4_diamonds["clarity"].mode()[0]
print("Mode of clarity for diamonds with cut of Ideal = " , mode_of_clarity)
# Out:
# Mode of clarity for diamonds with cut of Ideal =  VS2

# %% [markdown]
#                                 ___________________________TASK 41 _________________________

# %%
if "clarity_encoded" in diamonds.columns:
    diamonds = diamonds.drop(columns=["clarity_encoded"])

# %%
Quartile1 = diamonds["price"].quantile(0.25)
Quartile3 = diamonds["price"].quantile(0.75)
IQR = Quartile3 - Quartile1
lower = Quartile1 - 1.5*IQR
upper = Quartile3 + 1.5*IQR
CleanDiamonds = diamonds[(diamonds['price'] >= lower) & (diamonds['price'] <= upper)]
CleanDiamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50400 rows x 10 columns]

# %% [markdown]
#                                 ___________________________TASK 42 _________________________

# %%
MahamQuartile1 = diamonds["carat"].quantile(0.25)
MahamQuartile3 = diamonds["carat"].quantile(0.75)
IQR = MahamQuartile3 - MahamQuartile1
lower = MahamQuartile1 - 1.5*IQR
upper = MahamQuartile3 + 1.5*IQR
outliers = diamonds[(diamonds["carat"] < lower) | (diamonds["carat"] > upper)]
print("Lower Bound:", lower)
print("Upper Bound:", upper)
print("Outliers in 'carat' column:\n", outliers)
# Out:
# Lower Bound: -0.5599999999999999
# Upper Bound: 2.0
# Outliers in 'carat' column:
#         carat      cut color clarity  depth  table  price     x     y     z
# 12246   2.06  Premium     J      I1   61.2   58.0   5203  8.10  8.07  4.95
# 13002   2.14     Fair     J      I1   69.4   57.0   5405  7.74  7.70  5.36
# 13118   2.15     Fair     J      I1   65.5   57.0   5430  8.01  7.95  5.23
# 13757   2.22     Fair     J      I1   66.7   56.0   5607  8.04  8.02  5.36
# 13991   2.01     Fair     I      I1   67.4   58.0   5696  7.71  7.64  5.17
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27741   2.15    Ideal     G     SI2   62.6   54.0  18791  8.29  8.35  5.21
# 27742   2.04  Premium     H     SI1   58.1   60.0  18795  8.37  8.28  4.84
# 27744   2.29  Premium     I     SI1   61.8   59.0  18797  8.52  8.45  5.24
# 27746   2.07    Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# ...

# %% [markdown]
#                                 ___________________________TASK 43 _________________________

# %%
Q1= diamonds ['depth'].quantile(0.25)
Q3= diamonds ['depth'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print('Lower Bound: ',lower)
print('Upper Bound: ', upper)
# Out:
# Lower Bound:  58.75
# Upper Bound:  64.75

# %%
print("OUTLIERS IN DEPTH")
print(diamonds[(diamonds['depth'] < lower) & (diamonds['depth'] > upper)])
# Out:
# OUTLIERS IN DEPTH
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 44 _________________________

# %%
Q1= diamonds ['price'].quantile(0.25)
Q3= diamonds ['price'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print('Lower Bound: ',lower)
print('Upper Bound: ', upper)
# Out:
# Lower Bound:  -5611.375
# Upper Bound:  11885.625

# %%
print("OUTLIERS IN PRICE")
print(diamonds[(diamonds['price'] < lower) & (diamonds['price'] > upper)])
# Out:
# OUTLIERS IN PRICE
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 45 _________________________

# %%
Q1= diamonds ['carat'].quantile(0.25)
Q3= diamonds ['carat'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print('Lower Bound: ',lower)
print('Upper Bound: ', upper)
# Out:
# Lower Bound:  -0.5599999999999999
# Upper Bound:  2.0

# %%
print("OUTLIERS IN CARAT")
print(diamonds[(diamonds['carat'] < lower) & (diamonds['carat'] > upper)])
# Out:
# OUTLIERS IN CARAT
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 46 _________________________

# %%
X_Q1= diamonds ['x'].quantile(0.25)
X_Q3= diamonds ['x'].quantile(0.75)
IQR = X_Q3 - X_Q1
lower_x = X_Q1 - 1.5 * IQR
upper_x = X_Q3 + 1.5 * IQR
print('Lower Bound (x): ',lower_x)
print('Upper Bound (x): ', upper_x)

Y_Q1= diamonds ['y'].quantile(0.25)
Y_Q3= diamonds ['y'].quantile(0.75)
IQR = Y_Q3 - Y_Q1
lower_y = Y_Q1 - 1.5 * IQR
upper_y = Y_Q3 + 1.5 * IQR
print('\nLower Bound (y): ',lower_y)
print('Upper Bound (y): ', upper_y)
# Out:
# Lower Bound (x):  1.9649999999999999
# Upper Bound (x):  9.285
#
# Lower Bound (y):  1.9899999999999993
# Upper Bound (y):  9.27

# %%
print("OUTLIERS IN x")
print(diamonds[(diamonds['x'] < lower_x) & (diamonds['x'] > upper_x)])
print("\nOUTLIERS IN y")
print(diamonds[(diamonds['y'] < lower_y) & (diamonds['y'] > upper_y)])
# Out:
# OUTLIERS IN x
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []
#
# OUTLIERS IN y
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 47 _________________________

# %%
Q1= diamonds ['table'].quantile(0.25)
Q3= diamonds ['table'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print('Lower Bound: ',lower)
print('Upper Bound: ', upper)
# Out:
# Lower Bound:  51.5
# Upper Bound:  63.5

# %%
print("OUTLIERS IN TABLE")
print(diamonds[(diamonds['table'] < lower) & (diamonds['table'] > upper)])
# Out:
# OUTLIERS IN TABLE
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 48 _________________________

# %%
Q1= diamonds ['z'].quantile(0.25)
Q3= diamonds ['z'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print('Lower Bound: ',lower)
print('Upper Bound: ', upper)
# Out:
# Lower Bound:  1.2150000000000003
# Upper Bound:  5.734999999999999

# %%
print("OUTLIERS IN z")
print(diamonds[(diamonds['z'] < lower) & (diamonds['z'] > upper)])
# Out:
# OUTLIERS IN z
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z, clarity_numeric]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 49 _________________________

# %%
#Can not apply IQR on clarity column as it is of categorical type.
#converting the datatype of CLARITY column to numeric to apply IQR

# %%
diamonds['clarity_numeric'] = pd.Categorical(diamonds['clarity']).codes
Q1= diamonds ['clarity_numeric'].quantile(0.25)
Q3= diamonds ['clarity_numeric'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print('Lower Bound: ',lower)
print('Upper Bound: ', upper)
# Out:
# Lower Bound:  0.0
# Upper Bound:  8.0

# %%
print("OUTLIERS IN CLARITY")
print(diamonds[(diamonds['clarity_numeric'] < lower) & (diamonds['clarity_numeric'] > upper)])
# Out:
# OUTLIERS IN CLARITY
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z, clarity_numeric]
# Index: []

# %% [markdown]
#                                 ___________________________TASK 50 _________________________

# %%
Q1= diamonds ['price'].quantile(0.25)
Q3= diamonds ['price'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
no_outliers = diamonds[(diamonds['price'] > lower) & (diamonds['price'] < upper)]

mean_with_outlier = diamonds['price'].mean()
mean_without_outlier = no_outliers['price'].mean()

print("Mean With Outerliers: ", mean_with_outlier)
print("Mean Without Outerliers:", mean_without_outlier)

mean_differnce = mean_with_outlier - mean_without_outlier
print("Difference of means", mean_differnce)
# Out:
# Mean With Outerliers:  3932.799721913237
# Mean Without Outerliers: 3159.4608333333335
# Difference of means 773.3388885799036

# %% [markdown]
#                                 ___________________________TASK 51 _________________________

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(diamonds['price'], bins=30, edgecolor = 'blue')
plt.title("Histogram of Diamond Prices")
plt.xlabel("Price ($)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
#                                 ___________________________TASK 52 _________________________

# %%
plt.figure(figsize=(10, 6))
plt.scatter(diamonds['carat'], diamonds['price'], color='orange')
plt.title('Carat vs Price')
plt.xlabel("Carat")
plt.ylabel("Price ($)")
plt.show()

# %% [markdown]
#                                 ___________________________TASK 53 _________________________

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=diamonds['price'], color='red')
plt.title("Box Plot of Diamond Prices")
plt.xlabel("Price ($)")
plt.show()

# %% [markdown]
#                                 ___________________________TASK 54 _________________________

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(diamonds.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Heatmap of Correlation Matrix")
plt.show()

# %% [markdown]
#                                 ___________________________TASK 55 _________________________

# %%
plt.figure(figsize=(10, 5))
plt.hist(diamonds['depth'], bins = 40, color = 'pink', edgecolor = 'blue')
plt.title('Histogram of Depth') 
plt.xlabel('Depth') 
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#                                 ___________________________TASK 56 _________________________

# %%
plt.figure(figsize=(7,4))
sns.barplot(x='price', y='cut', data = diamonds, estimator=lambda x: x.mean(), color = 'olive')
plt.xlabel('Average Price')
plt.ylabel('Cut')
plt.title('Average Diamond Price by Cut')
plt.show()

# %% [markdown]
#                                 ___________________________TASK 57 _________________________

# %%
plt.figure(figsize=(8, 4))
plt.scatter(diamonds['carat'], diamonds['depth'], color='purple')
plt.title('Carat vs Depth')
plt.xlabel("Carat")
plt.ylabel("Depth")
plt.show()

# %% [markdown]
#                                 ___________________________TASK 58 _________________________

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x="clarity", y="price", hue="clarity", data=diamonds, palette="Set2", legend=False)
plt.xlabel("Clarity")
plt.ylabel("Price")
plt.title("Box Plot of Diamond Prices by Clarity")
plt.show()

# %% [markdown]
#                                 ___________________________TASK 59 _________________________

# %%
total_diamonds = len(diamonds)
diamonds_above_5000 = len(diamonds[diamonds["price"] > 5000])
probability = diamonds_above_5000 / total_diamonds
print('Probability of selecting a diamond with a price above $5000: ', probability)
# Out:
# Probability of selecting a diamond with a price above $5000:  0.27278457545420837

# %% [markdown]
#                                 ___________________________TASK 60 _________________________

# %%
diamonds_above_2000 = diamonds[diamonds["price"] > 2000]
total_above_2000 = len(diamonds_above_2000)
ideal_above_2000 = len(diamonds_above_2000[diamonds_above_2000["cut"] == "Ideal"])
conditional_probability = ideal_above_2000 / total_above_2000
print("Conditional Probability of Ideal cut given price > $2000: ", conditional_probability)
# Out:
# Conditional Probability of Ideal cut given price > $2000:  0.3346113745669794
