# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.size
# Out:
# 750

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   148.000000    149.000000   149.000000
# mean       8.043333     3.052027      4.511409     1.944966
# std       19.956592     0.433224      8.996204     8.976948
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max      225.000000     4.400000    111.500000   110.400000

# %%
df.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Sepal.Length    0
# Sepal.Width     2
# Petal.Length    1
# Petal.Width     1
# Species         0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isna().sum()
# Out:
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
m = df['Sepal.Width'].mean()
m
# Out:
# np.float64(3.0520270270270276)

# %%
df['Sepal.Width'].fillna(m)
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: Sepal.Width, Length: 150, dtype: float64

# %%
df.groupby('Species').mean()
# Out:
#             Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa            11.606     3.427083      3.706122     2.493878
# versicolor         5.936     2.770000      4.260000     1.326000
# virginica          6.588     2.974000      5.552000     2.026000

# %%
df.groupby('Species').agg({'Sepal.Length': ['mean','median','std'], 'Petal.Length': ['mean','median','std'],
                           'Sepal.Width': ['mean','median','std'], 'Petal.Width': ['mean','median','std']})
# Out:
#            Sepal.Length                   Petal.Length                    \
#                    mean median        std         mean median        std
# Species
# setosa           11.606    5.0  34.507062     3.706122   1.50  15.720918
# versicolor        5.936    5.9   0.516171     4.260000   4.35   0.469911
# virginica         6.588    6.5   0.635880     5.552000   5.55   0.551895
#
#            Sepal.Width                  Petal.Width
#                   mean median       std        mean median        std
# Species
# setosa        3.427083    3.4  0.375720    2.493878    0.2  15.736640
# versicolor    2.770000    2.8  0.313798    1.326000    1.3   0.197753
# virginica     2.974000    3.0  0.322497    2.026000    2.0   0.274650

# %%
avg = df['Sepal.Length'].mean()
avg
# Out:
# np.float64(8.043333333333333)

# %%
std = df['Sepal.Length'].std()
std
# Out:
# np.float64(19.95659187547103)

# %%
df[df['Sepal.Length']> avg]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 19         115.1          3.8           1.5          0.3  setosa
# 35         225.0          3.2           1.2          0.2  setosa

# %%
df[df['Sepal.Width']> 3.0]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [66 rows x 5 columns]

# %%
lower = avg - 2 * std
lower
# Out:
# np.float64(-31.869850417608728)

# %%
upper = avg + 2 * std
upper
# Out:
# np.float64(47.95651708427539)

# %%
df[(df['Sepal.Length'] > lower) & (df['Sepal.Length'] < upper)]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [148 rows x 5 columns]

# %%
df[(df['Sepal.Length'] < lower) & (df['Sepal.Length'] > upper)]
# Out:
# Empty DataFrame
# Columns: [Sepal.Length, Sepal.Width, Petal.Length, Petal.Width, Species]
# Index: []

# %%
Q1 = df['Sepal.Length'].quantile(0.25)
Q3 = df['Sepal.Length'].quantile(0.75)
IQR = Q3-Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
df[df['Sepal.Length']>upper]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 19         115.1          3.8           1.5          0.3  setosa
# 35         225.0          3.2           1.2          0.2  setosa
